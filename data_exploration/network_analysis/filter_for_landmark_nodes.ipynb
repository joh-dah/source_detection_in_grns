# %%
# create a list from landmark_genes.txt
landmark_genes = []
with open('../data/landmark_genes.txt') as f:
    for line in f:
        landmark_genes.append(line.strip())

# %%
print(len(landmark_genes))
# Out:
# 962

# %%
import pandas as pd


import pandas as pd
import numpy as np
import os

df_network = pd.read_csv('../data/ACH-000681_A549_LUAD.csv', index_col='Row')
df_network
# Out:
#              A1BG      A1CF       A2M     A2ML1   A3GALT2    A4GALT     A4GNT  \
# Row
# AHR     -1.456700 -1.906796 -1.546377 -1.841165 -0.622212 -0.448640 -1.606225
# AHRR    -1.299728 -1.957249 -1.778370 -1.738238 -0.627832 -0.303684 -1.642907
# AIRE    -0.542148  2.379225  0.916917  3.211573  0.085858 -2.216719  2.000027
# ALX1    -1.079603  3.246602  1.990148  0.369819  0.371557 -2.693602  1.534563
# ALX3    -0.294882  0.069046  2.155370  0.371244  0.037834 -2.847364  0.695113
# ...           ...       ...       ...       ...       ...       ...       ...
# ZSCAN31  0.139920 -1.693352 -0.790256 -0.827846  1.788688 -0.000075 -0.718153
# ZSCAN4  -0.402627 -0.161515  0.913768 -0.446397  0.202028 -0.593820 -0.164244
# ZSCAN5A -0.705373 -0.925994 -1.132814  0.118586 -1.048175  0.680608 -1.863631
# ZSCAN5C  0.059676 -0.488809  0.839237 -0.743959 -0.243809 -1.555907  1.113240
# ZSCAN9  -0.303943  1.827275  2.404545  2.888207  0.187057 -2.433714  0.573441
#
# ...

# %%
# what is the smallest and largest value in the network?
df_network.min().min(), df_network.max().max()
# Out:
# (np.float64(-79.0114192078011), np.float64(43.9616110080029))

# %%
# create a new dataframe only with columns that are in landmark_genes
df_network_landmark = df_network[df_network.columns.intersection(landmark_genes)]

# %%
df_network_landmark = df_network_landmark[df_network_landmark.index.isin(landmark_genes)]
df_network_landmark
# Out:
#            ABCB6     ABCC5     ABCF1     ABCF3     ABHD4     ABHD6      ABL1  \
# Row
# ARID5B  0.369725  0.259312 -2.328929 -2.318670 -2.418631 -2.676081 -2.605227
# ARNT2   0.402755 -0.337742  2.395118  0.741693 -1.073135 -2.151133 -0.323495
# ATF1    0.585678  0.857841 -0.691066  0.242941 -1.522633 -0.072706 -1.020879
# ATF5    0.676865 -0.134194 -0.835057 -1.512513 -0.475035  0.233405 -1.492998
# ATF6    1.274045  0.658433  0.458774  0.097618 -0.342695 -0.152887  0.953231
# ...          ...       ...       ...       ...       ...       ...       ...
# TP53   -0.979184 -0.442691 -1.508846 -1.126241  0.307448 -1.581236 -2.158444
# XBP1   -0.010955  1.520573 -2.370944 -1.600954 -1.272185 -1.946767 -3.767756
# ZNF274 -0.152501 -0.137913 -0.222967 -0.721044 -0.421026 -0.524651 -1.389909
# ZNF586  0.341329 -1.951228  0.232061  2.106346  0.725767  1.793261  3.264234
# ZNF589  0.590542 -0.759346 -0.760695 -0.082025 -0.734872  0.863169  0.519139
#
# ...

# %%
# get a list of row names
row_names = df_network_landmark.index.tolist()
print(len(row_names))
# get the difference between the landmark_genes and row_names
diff = list(set(landmark_genes) - set(row_names))
print(len(diff))
# add the missing genes to the dataframe. fill the values with -1000
for gene in diff:
    df_network_landmark.loc[gene] = -1000
# Out:
# 65
# 897

# %%
#sort columns and rows alphabetically
df_network_landmark = df_network_landmark.sort_index(axis=0)
df_network_landmark = df_network_landmark.sort_index(axis=1)

# %%
df_network_landmark
# Out:
#               ABCB6        ABCC5        ABCF1        ABCF3        ABHD4  \
# Row
# ABCB6  -1000.000000 -1000.000000 -1000.000000 -1000.000000 -1000.000000
# ABCC5  -1000.000000 -1000.000000 -1000.000000 -1000.000000 -1000.000000
# ABCF1  -1000.000000 -1000.000000 -1000.000000 -1000.000000 -1000.000000
# ABCF3  -1000.000000 -1000.000000 -1000.000000 -1000.000000 -1000.000000
# ABHD4  -1000.000000 -1000.000000 -1000.000000 -1000.000000 -1000.000000
# ...             ...          ...          ...          ...          ...
# ZNF395 -1000.000000 -1000.000000 -1000.000000 -1000.000000 -1000.000000
# ZNF451 -1000.000000 -1000.000000 -1000.000000 -1000.000000 -1000.000000
# ZNF586     0.341329    -1.951228     0.232061     2.106346     0.725767
# ZNF589     0.590542    -0.759346    -0.760695    -0.082025    -0.734872
# ZW10   -1000.000000 -1000.000000 -1000.000000 -1000.000000 -1000.000000
#
#               ABHD6         ABL1        ACAA1        ACAT2        ACBD3  ...  \
# ...

# %%
# store the new dataframe in a new csv file
df_network_landmark.to_csv('../data/ACH-000012_A549_landmark.csv')
